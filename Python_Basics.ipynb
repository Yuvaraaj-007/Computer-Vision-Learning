# %% [markdown]
# <a href="https://colab.research.google.com/github/Yuvaraaj-007/Computer-Vision-Learning/blob/main/Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello, World!")
# Out:
# Hello, World!

# %%
print ("My aim is Computer vision")
# Out:
# My aim is Computer vision

# %%
name = "Yuvaraaj"
age = 20;
sub = "Mathematics"
print("My name is", name)
print("My age is", age)
print("My favourite subject is", sub)
# Out:
# My name is Yuvaraaj
# My age is 20
# My favourite subject is Mathematics

# %%
a = int(input("Enter the length"))
b = int(input("Enter the breadth"))
c = a*b
print("The area of the rectangle is : ",c," units." )
# Out:
# Enter the length10
# Enter the breadth20
# The area of the rectangle is :  200  units.

# %%
students = [
    ["Yuvaraaj", 20, "ECE"],
    ["Arun", 21, "CSE"],
    ["Priya", 20, "EEE"]
]
print(students)
print(students[0][0], students[1][0], students[2][0])
print(students[1][2])
print(students[2][1])
# Out:
# [['Yuvaraaj', 20, 'ECE'], ['Arun', 21, 'CSE'], ['Priya', 20, 'EEE']]
# Yuvaraaj Arun Priya
# CSE
# 20

# %%
num=[i*10 for i in range(1,6)]
print(num)
# Out:
# [10, 20, 30, 40, 50]

# %%
names = ["apple", "banana", "orange"]
name = [len(a) for a in names];
print(name)
# Out:
# [5, 6, 6]

# %%
a = int(input("Enter number 1 : "))
b = int(input("Enter number 2 : "))
try:
  a/b
except ZeroDivisionError:
  print("Cannot divide by zero")
finally:
  print("Program ended")
# Out:
# Enter number 1 : 5
# Enter number 2 : 0
# Cannot divide by zero
# Program ended

# %%
import numpy
print(numpy.__version__)
# Out:
# 2.0.2
